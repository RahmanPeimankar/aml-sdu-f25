# %%
# Install langchain
# !pip install langchain

# Install vectorStore
# !pip install faiss-cpu

# Install gpt4all
# !pip install gpt4all

# Install huggingfaceHub
# !pip install huggingface-hub

# Install PyPdf for working with PDFs
# !pip install pypdf
# Out:
# Collecting langchain
#   Downloading langchain-0.3.18-py3-none-any.whl (1.0 MB)
#      ---------------------------------------- 1.0/1.0 MB 15.9 MB/s eta 0:00:00
# Collecting langchain-core<1.0.0,>=0.3.34
#   Downloading langchain_core-0.3.35-py3-none-any.whl (413 kB)
#      ------------------------------------- 413.2/413.2 kB 25.2 MB/s eta 0:00:00
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\abpe\anaconda3\lib\site-packages (from langchain) (2.10.6)
# Collecting numpy<2,>=1.26.4
#   Downloading numpy-1.26.4-cp39-cp39-win_amd64.whl (15.8 MB)
#      --------------------------------------- 15.8/15.8 MB 59.4 MB/s eta 0:00:00
# Requirement already satisfied: requests<3,>=2 in c:\users\abpe\anaconda3\lib\site-packages (from langchain) (2.28.1)
# Collecting langchain-text-splitters<1.0.0,>=0.3.6
#   Downloading langchain_text_splitters-0.3.6-py3-none-any.whl (31 kB)
# Collecting aiohttp<4.0.0,>=3.8.3
#   Downloading aiohttp-3.11.12-cp39-cp39-win_amd64.whl (442 kB)
#      ------------------------------------- 442.4/442.4 kB 13.5 MB/s eta 0:00:00
# Requirement already satisfied: PyYAML>=5.3 in c:\users\abpe\anaconda3\lib\site-packages (from langchain) (6.0)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in c:\users\abpe\anaconda3\lib\site-packages (from langchain) (1.4.39)
# Collecting tenacity!=8.4.0,<10,>=8.1.0
#   Downloading tenacity-9.0.0-py3-none-any.whl (28 kB)
# Collecting async-timeout<5.0.0,>=4.0.0
#   Downloading async_timeout-4.0.3-py3-none-any.whl (5.7 kB)
# Collecting langsmith<0.4,>=0.1.17
#   Downloading langsmith-0.3.8-py3-none-any.whl (332 kB)
#      ---------------------------------------- 332.8/332.8 kB ? eta 0:00:00
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.2-py2.py3-none-any.whl (7.6 kB)
# Collecting yarl<2.0,>=1.17.0
#   Downloading yarl-1.18.3-cp39-cp39-win_amd64.whl (90 kB)
#      ---------------------------------------- 91.0/91.0 kB ? eta 0:00:00
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.1.0-cp39-cp39-win_amd64.whl (28 kB)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.5.0-cp39-cp39-win_amd64.whl (51 kB)
#      ---------------------------------------- 51.8/51.8 kB 2.6 MB/s eta 0:00:00
# Requirement already satisfied: attrs>=17.3.0 in c:\users\abpe\anaconda3\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (21.4.0)
# Collecting propcache>=0.2.0
#   Downloading propcache-0.2.1-cp39-cp39-win_amd64.whl (44 kB)
#      ---------------------------------------- 45.0/45.0 kB ? eta 0:00:00
# Collecting aiohappyeyeballs>=2.3.0
#   Downloading aiohappyeyeballs-2.4.6-py3-none-any.whl (14 kB)
# Collecting packaging<25,>=23.2
#   Downloading packaging-24.2-py3-none-any.whl (65 kB)
#      ---------------------------------------- 65.5/65.5 kB 3.5 MB/s eta 0:00:00
# Collecting jsonpatch<2.0,>=1.33
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: typing-extensions>=4.7 in c:\users\abpe\anaconda3\lib\site-packages (from langchain-core<1.0.0,>=0.3.34->langchain) (4.12.2)
# Collecting requests-toolbelt<2.0.0,>=1.0.0
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
#      ---------------------------------------- 54.5/54.5 kB ? eta 0:00:00
# Collecting zstandard<0.24.0,>=0.23.0
#   Downloading zstandard-0.23.0-cp39-cp39-win_amd64.whl (495 kB)
#      ---------------------------------------- 495.5/495.5 kB ? eta 0:00:00
# Collecting orjson<4.0.0,>=3.9.14
#   Downloading orjson-3.10.15-cp39-cp39-win_amd64.whl (133 kB)
#      ---------------------------------------- 133.4/133.4 kB ? eta 0:00:00
# Collecting httpx<1,>=0.23.0
#   Downloading httpx-0.28.1-py3-none-any.whl (73 kB)
#      ---------------------------------------- 73.5/73.5 kB ? eta 0:00:00
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\abpe\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.27.2)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\abpe\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\abpe\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (1.26.11)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\abpe\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\abpe\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (2022.9.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\abpe\anaconda3\lib\site-packages (from requests<3,>=2->langchain) (2.0.4)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\abpe\anaconda3\lib\site-packages (from SQLAlchemy<3,>=1.4->langchain) (1.1.1)
# Collecting httpcore==1.*
#   Downloading httpcore-1.0.7-py3-none-any.whl (78 kB)
#      ---------------------------------------- 78.6/78.6 kB ? eta 0:00:00
# Requirement already satisfied: anyio in c:\users\abpe\anaconda3\lib\site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (3.5.0)
# Collecting h11<0.15,>=0.13
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ---------------------------------------- 58.3/58.3 kB ? eta 0:00:00
# Collecting jsonpointer>=1.9
#   Downloading jsonpointer-3.0.0-py2.py3-none-any.whl (7.6 kB)
# Requirement already satisfied: sniffio>=1.1 in c:\users\abpe\anaconda3\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.2.0)
# Installing collected packages: zstandard, tenacity, propcache, packaging, orjson, numpy, multidict, jsonpointer, h11, frozenlist, async-timeout, aiohappyeyeballs, yarl, requests-toolbelt, jsonpatch, httpcore, aiosignal, httpx, aiohttp, langsmith, langchain-core, langchain-text-splitters, langchain
#   Attempting uninstall: tenacity
#     Found existing installation: tenacity 8.0.1
#     Uninstalling tenacity-8.0.1:
#       Successfully uninstalled tenacity-8.0.1
#   Attempting uninstall: packaging
#     Found existing installation: packaging 21.3
#     Uninstalling packaging-21.3:
#       Successfully uninstalled packaging-21.3
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.24.4
#     Uninstalling numpy-1.24.4:
#       Successfully uninstalled numpy-1.24.4
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\abpe\\Anaconda3\\Lib\\site-packages\\~umpy\\.libs\\libopenblas64__v0.3.21-gcc_10_3_0.dll'
# Consider using the `--user` option or check the permissions.
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.10.0-cp39-cp39-win_amd64.whl (13.7 MB)
#      ---------------------------------------- 13.7/13.7 MB 6.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy<3.0,>=1.25.0 in c:\users\abpe\anaconda3\lib\site-packages (from faiss-cpu) (1.26.4)
# Requirement already satisfied: packaging in c:\users\abpe\anaconda3\lib\site-packages (from faiss-cpu) (24.2)
# Installing collected packages: faiss-cpu
# Successfully installed faiss-cpu-1.10.0
# Collecting gpt4all
#   Downloading gpt4all-2.8.2-py3-none-win_amd64.whl (119.6 MB)
#      -------------------------------------- 119.6/119.6 MB 4.0 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\abpe\anaconda3\lib\site-packages (from gpt4all) (4.12.2)
# Requirement already satisfied: tqdm in c:\users\abpe\anaconda3\lib\site-packages (from gpt4all) (4.64.1)
# Requirement already satisfied: requests in c:\users\abpe\anaconda3\lib\site-packages (from gpt4all) (2.28.1)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\abpe\anaconda3\lib\site-packages (from requests->gpt4all) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\abpe\anaconda3\lib\site-packages (from requests->gpt4all) (2022.9.14)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\abpe\anaconda3\lib\site-packages (from requests->gpt4all) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\abpe\anaconda3\lib\site-packages (from requests->gpt4all) (1.26.11)
# Requirement already satisfied: colorama in c:\users\abpe\anaconda3\lib\site-packages (from tqdm->gpt4all) (0.4.5)
# Installing collected packages: gpt4all
# Successfully installed gpt4all-2.8.2
# Collecting huggingface-hub
#   Downloading huggingface_hub-0.28.1-py3-none-any.whl (464 kB)
#      ------------------------------------- 464.1/464.1 kB 14.2 MB/s eta 0:00:00
# Requirement already satisfied: filelock in c:\users\abpe\anaconda3\lib\site-packages (from huggingface-hub) (3.6.0)
# Requirement already satisfied: requests in c:\users\abpe\anaconda3\lib\site-packages (from huggingface-hub) (2.28.1)
# Collecting fsspec>=2023.5.0
#   Downloading fsspec-2025.2.0-py3-none-any.whl (184 kB)
#      ---------------------------------------- 184.5/184.5 kB ? eta 0:00:00
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\abpe\anaconda3\lib\site-packages (from huggingface-hub) (4.64.1)
# Requirement already satisfied: packaging>=20.9 in c:\users\abpe\anaconda3\lib\site-packages (from huggingface-hub) (24.2)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\abpe\anaconda3\lib\site-packages (from huggingface-hub) (4.12.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\abpe\anaconda3\lib\site-packages (from huggingface-hub) (6.0)
# Requirement already satisfied: colorama in c:\users\abpe\anaconda3\lib\site-packages (from tqdm>=4.42.1->huggingface-hub) (0.4.5)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\abpe\anaconda3\lib\site-packages (from requests->huggingface-hub) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\abpe\anaconda3\lib\site-packages (from requests->huggingface-hub) (2022.9.14)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\abpe\anaconda3\lib\site-packages (from requests->huggingface-hub) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\abpe\anaconda3\lib\site-packages (from requests->huggingface-hub) (1.26.11)
# Installing collected packages: fsspec, huggingface-hub
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2022.7.1
#     Uninstalling fsspec-2022.7.1:
#       Successfully uninstalled fsspec-2022.7.1
# Successfully installed fsspec-2025.2.0 huggingface-hub-0.28.1
# Collecting pypdf
#   Downloading pypdf-5.3.0-py3-none-any.whl (300 kB)
#      ------------------------------------- 300.7/300.7 kB 19.4 MB/s eta 0:00:00
# Requirement already satisfied: typing_extensions>=4.0 in c:\users\abpe\anaconda3\lib\site-packages (from pypdf) (4.12.2)
# Installing collected packages: pypdf
# Successfully installed pypdf-5.3.0
